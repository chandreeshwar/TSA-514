# %%
# Upload the Kaggle API key
from google.colab import files
files.upload()  # This will prompt you to upload 'kaggle.json' (Kaggle API token)
# Out:
#      <input type="file" id="files-96d433f9-b63d-46df-bf0f-e932acd4cded" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-96d433f9-b63d-46df-bf0f-e932acd4cded">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

data = pd.read_csv("time_series_sales.csv")
print(data.columns)
# Out:
# Index(['date', 'sales', 'temperature', 'holiday'], dtype='object')

# %%
data = pd.read_csv("time_series_sales.csv", parse_dates=['date'], index_col='date')

# %%
import matplotlib.pyplot as plt

# Plot the time series data
plt.figure(figsize=(12, 6))
plt.plot(data['sales'], label='Sales Data')  # Assuming 'sales' is the column you want to plot
plt.title('Line plot of Sales Data')  # Set the title of the plot
plt.xlabel('Date')  # Label for the x-axis
plt.ylabel('Sales')  # Label for the y-axis
plt.legend()
plt.grid(True)
plt.show()

# %%
# Resample the data by month and calculate the mean for the 'sales' column
monthly_data = data['sales'].resample('M').mean()

# Plot the resampled data
plt.figure(figsize=(12, 6))
plt.plot(monthly_data, label='Monthly Mean of Sales')
plt.title('Monthly Sales Data')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-5-30e878577248>:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_data = data['sales'].resample('M').mean()

# %%
# Plot histogram for 'sales' column
plt.figure(figsize=(10, 5))
data['sales'].hist(bins=30)
plt.title('Histogram of Sales')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()
